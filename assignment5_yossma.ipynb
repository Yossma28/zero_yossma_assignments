# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import csv
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler

# %%
File = pd.read_csv('C:/Users/yossm/Downloads/records.csv')

# %%
File
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                      1  265000.00               1.9           130    1
# 1                      0  263358.03               1.1           136    1
# 2                      0  162000.00               1.3           129    1
# 3                      0  210000.00               1.9           137    1
# 4                      0  327000.00               2.7           116    0
# ..                   ...        ...               ...           ...  ...
# 294                    1  155000.00               1.1           143    1
# 295                    0  270000.00               1.2           139    0
# 296                    0  742000.00               0.8           138    0
# 297                    0  140000.00               1.4           140    1
# 298                    0  395000.00               1.6           136    1
#
#      smoking  time  DEATH_EVENT
# 0          0     4            1
# 1          0     6            1
# 2          1     7            1
# 3          0     7            1
# 4          0     8            1
# ..       ...   ...          ...
# 294        1   270            0
# 295        0   271            0
# 296        0   278            0
# 297        1   280            0
# 298        1   285            0
#
# [299 rows x 13 columns]

# %%
features = File.drop('sex', axis=1)  # Assuming 'target_column' is your target variable
target = File['sex']

# %%
pca = PCA(n_components=2)  # Here, we're keeping 2 components

# %%
scaler = StandardScaler()
scaled_features = scaler.fit_transform(features)

# %%
pca = PCA(n_components=4)
pca.fit(scaled_features)

pca_X = pca.transform(scaled_features)

# %%
PC1 = pca_X[:, 0]
PC2 = pca_X[:, 1]
PC3 = pca_X[:,2]
PC4 = pca_X[:,3]

# %%
plt.scatter(PC1, PC2, PC3, PC4,alpha=0.8)
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA of Heart Dataset PC1 vs PC2')
# Out:
# c:\Users\yossm\anaconda3\Lib\site-packages\matplotlib\collections.py:963: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# Text(0.5, 1.0, 'PCA of Heart Dataset PC1 vs PC2')

# %%
plt.scatter(PC3, PC4,alpha=0.8)
plt.xlabel('Principal Component 3')
plt.ylabel('Principal Component 4')
plt.title('PCA of Heart Dataset PC3 vs PC4')
# Out:
# Text(0.5, 1.0, 'PCA of Heart Dataset PC3 vs PC4')
